# %% [markdown]
# # BASEBALL

# %% [markdown]
# Baseball statistics play an important role in evaluating the progress of a player or team.
#
# Since the flow of a baseball game has natural breaks to it, and normally players act individually rather than performing in clusters, the sport lends itself to easy record-keeping and statistics. Statistics have been kept for professional baseball since the creation of the National League and American League, now part of Major League Baseball.
#
# Many statistics are also available from outside Major League Baseball, from leagues such as the National Association of Professional Base Ball Players and the Negro leagues, although the consistency of whether these records were kept, of the standards with respect to which they were calculated, and of their accuracy has varied.

# %% [markdown]
# # Data Description

# %% [markdown]
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.

# %% [markdown]
# # Loading the Dataset

# %%
import pandas as pd
import numpy as np

path ='https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv'
df= pd.read_csv(path)

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# # Details About the Columns

# %% [markdown]
#     1. W
#
# This column shows the Total no of wins of each team
#
#     2. R
#
# This column shows the  Runs scored: number of times a player crosses home plate
#
#
#     3. AB
#
# This column shows the At bat: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction
#
#
#     4. H
#
# This column shows the Hit: reaching base because of a batted, fair ball without error by the defense
#
#
#     5. 2B
#
# This column shows the Double: hits on which the batter reaches second base safely without the contribution of a fielding error
#
#     6. 3B
#
# This column shows the  Triple: hits on which the batter reaches third base safely without the contribution of a fielding error
#
#     7. HR
#
# This column shows the Home runs: hits on which the batter successfully touched all four bases, without the contribution of a fielding error
#
#     8. BB
#
# This column shows the Base on balls (also called a "walk"): times pitching four balls, allowing the batter to take first base
#
#     9. SO
#
# This column shows the Plate appearances per strikeout: number of times a batter strikes out to their plate appearance
#
#     10. RA
#
# This column shows the  Run average: number of runs allowed times nine divided by innings pitched
#
#     11. ER
#
# This column shows the  Earned run: number of runs that did not occur as a result of errors or passed balls
#
#     12. ERA
#
# This column shows the Earned run average: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched
#
#     13. CG
#
# This column shows the  Complete game: number of games where player was the only pitcher for their team
#
#     14. SHO
#
# This column shows the Shutout: number of complete games pitched with no runs allowed
#
#     15. SV
#
# This column shows the  Save opportunity: When a pitcher 1) enters the game with a lead of three or fewer runs and pitches at least one inning, 2) enters the game with the potential tying run on base, at bat, or on deck, or 3) pitches three or more innings with a lead and is credited with a save by the official scorer
#
#     16. E
#
# This column shows the Errors: number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a result

# %% [markdown]
# # Checking for the Columns containing Null , Blank Or Empty Values

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# Checking the presence of NULL BLANK or EMPTY VALUES through HeatMap

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df.isnull())
plt.title("Null Values")
plt.show()

# %% [markdown]
# We can see that there arte no Null Nlank Or Empty Values present in the Datset

# %% [markdown]
# # Checking and Transforming the Data types of the Columns To Same DataTypes for Better Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# We can see that all the datas present in different columns are of same data types

# %% [markdown]
# Checking for Duplicated Values

# %%
sum(df.duplicated())
# Out:
# 0

# %% [markdown]
# No Duplicate values are Present

# %% [markdown]
# # EDA

# %%
sns.lineplot(x='W',y='R',data=df)

# %%
sns.barplot(data=df, x="W", y="AB")

# %%
df.plot.hexbin(x='W', y='H', gridsize=15)

# %%
df.plot.scatter(x='R',y='2B')

# %%
sns.displot(df['3B'])

# %%
sns.countplot(df['HR'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.displot(df['BB'],kind='kde',color='blue')

# %%
sns.countplot(y=df['SO'])

# %%
df.plot.hexbin(x='W', y='SB', gridsize=15)

# %%
sns.lineplot(x='W',y='RA',data=df)

# %%
df.plot.scatter(x='R',y='ER')

# %%
sns.displot(df['ERA'],kind='kde',color='blue')

# %%
sns.barplot(data=df, x="W", y="CG")

# %%
sns.barplot(data=df, x="W", y="SHO")

# %%
sns.lineplot(x='W',y='SV',data=df)

# %%
sns.lineplot(x='W',y='E',data=df)

# %%
df.plot.line(subplots = True, figsize=(20,20))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f29083e96d0>,
# ...
#       dtype=object)

# %%
df.plot.bar(subplots= True,stacked= False, figsize=(20,30))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f2907ded290>,
# ...
#       dtype=object)

# %%
df.hist(figsize=(15,30),layout=(9,4),bins=15,legend=True)
plt.show()

# %%
df.plot.line(figsize=(10,8))

# %% [markdown]
# * Outputs
#
# 1. Shut outs and Complete Game occur very rarely now-a-days which we can definately see in violinplot of these variable.
#
# 2. An Errors does not count as a hit but still counts as an at bat for the batter, So need to dive into how much Error are contributing to at bat.
#
# 3. Most of saves are between 30 & 50. Saves doesnot entitle pitcher as wining pitcher but still it bring wins for team.It will be interesting what relation wins and save held or how much saves contribute in win.
#
# 4. Run average, Earned run and Earned run average are important for pitcher statstics. We can see there is not much difference in plot of Earned run and Run Average, so from here we can conclude that Unearned Run doesnot making much difference in wins.
#
# 5. Homeruns (125 to 175 peak) are more than triples (20 to 40 majority) so most of good shot by battar directly convert into homeruns.
#
# 6. As we know pitcher try to keep Earned run Average low which eventually lead to wins. Here for most of game ERA is around 3.5-4.5.
#
# 7. Let consider violinplot of doubles and base on balls. We know that if pitcher pitched ball for consecutive 4 ball then Base is awarded to batter. Clearly More runs comes from base of ball than doubles.

# %% [markdown]
# # COORELATION

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
df.corr()['W'].sort_values()
# Out:
# ERA   -0.819600
# RA    -0.812952
# ER    -0.809435
# 3B    -0.251118
# SB    -0.157234
# E     -0.089485
# AB    -0.087947
# H      0.037612
# CG     0.080533
# SO     0.111850
# HR     0.307407
# 2B     0.427797
# R      0.430751
# SHO    0.471805
# BB     0.484342
# SV     0.666530
# W      1.000000
# Name: W, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(), annot=True, linewidths=0.5,linecolor="black", fmt='.2f')

# %% [markdown]
# # Descriptive Statistics

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
plt.figure(figsize=(15,7))
sns.heatmap(round(df.describe()[1:].transpose(),2), annot=True, linewidths=0.5,linecolor="black", fmt='f')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# # Checking Data To Remove Skewness

# %%
my_column1 = df.pop('W')
df.insert(16,'W', my_column1) 


df.head()
# Out:
#      R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  SV  \
# 0  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8  56
# 1  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12  45
# 2  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10  38
# 3  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9  37
# 4  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12  35
#
#      E   W
# 0   88  95
# 1   86  83
# 2   79  81
# 3  101  76
# 4   86  74

# %%
df.iloc[:,:-1].skew()
# Out:
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
df.plot(kind='density', subplots=True, layout=(5,4), sharex=False, legend=True, fontsize=1, figsize=(22,12))
plt.show()

# %%
# Using yeo-johnson method to remove the skewness
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')

# %%
skewed_features = ["R","CG","SV","SHO","ER","ERA","HR","H"]

# %%
df[skewed_features] = scaler.fit_transform(df[skewed_features].values)
df[skewed_features].head()
# Out:
#      R        CG        SV       SHO        ER       ERA        HR    H
# 0  0.0 -0.359844  1.546378 -0.789579 -0.497425 -0.500893 -0.764626  0.0
# 1  0.0 -0.359844  0.360444  0.251775  0.257974  0.261806 -0.158581  0.0
# 2  0.0  1.993513 -0.607594 -0.245393 -0.746906 -0.636459 -0.689676  0.0
# 3  0.0  1.220103 -0.764453 -0.510759  0.113575  0.060804 -0.879049  0.0
# 4  0.0  1.220103 -1.095010  0.251775  1.582654  1.520959 -0.329850  0.0

# %%
df.skew()
# Out:
# R      0.000000
# AB     0.183437
# H      0.000000
# 2B    -0.230650
# 3B     0.129502
# HR    -0.000065
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER    -0.001940
# ERA    0.001746
# CG    -0.059785
# SHO    0.006560
# SV     0.000836
# E      0.890132
# W      0.047089
# dtype: float64

# %% [markdown]
# # Outliers Checking

# %%
import warnings
warnings.filterwarnings('ignore')
df.plot(kind='box',subplots=True, layout=(6,3), figsize=[30,20])
# Out:
# R         AxesSubplot(0.125,0.772143;0.227941x0.107857)
# AB     AxesSubplot(0.398529,0.772143;0.227941x0.107857)
# H      AxesSubplot(0.672059,0.772143;0.227941x0.107857)
# 2B        AxesSubplot(0.125,0.642714;0.227941x0.107857)
# 3B     AxesSubplot(0.398529,0.642714;0.227941x0.107857)
# HR     AxesSubplot(0.672059,0.642714;0.227941x0.107857)
# BB        AxesSubplot(0.125,0.513286;0.227941x0.107857)
# SO     AxesSubplot(0.398529,0.513286;0.227941x0.107857)
# SB     AxesSubplot(0.672059,0.513286;0.227941x0.107857)
# RA        AxesSubplot(0.125,0.383857;0.227941x0.107857)
# ER     AxesSubplot(0.398529,0.383857;0.227941x0.107857)
# ERA    AxesSubplot(0.672059,0.383857;0.227941x0.107857)
# CG        AxesSubplot(0.125,0.254429;0.227941x0.107857)
# SHO    AxesSubplot(0.398529,0.254429;0.227941x0.107857)
# SV     AxesSubplot(0.672059,0.254429;0.227941x0.107857)
# E            AxesSubplot(0.125,0.125;0.227941x0.107857)
# W         AxesSubplot(0.398529,0.125;0.227941x0.107857)
# ...

# %% [markdown]
# # IQR Proximity Rule
#
# Z - Score Technique

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z.shape
# Out:
# (30, 17)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
len(np.where(z>3)[0])
# Out:
# 1

# %% [markdown]
# # Feature Engineering ( Variantion Inflation Factor )

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
df.corr()
# Out:
#             W   R  AB   H        2B        3B        HR        BB        SO  \
# W    1.000000 NaN NaN NaN  0.433093 -0.247935  0.326265  0.478887  0.124063
# R         NaN NaN NaN NaN       NaN       NaN       NaN       NaN       NaN
# AB        NaN NaN NaN NaN       NaN       NaN       NaN       NaN       NaN
# H         NaN NaN NaN NaN       NaN       NaN       NaN       NaN       NaN
# 2B   0.433093 NaN NaN NaN  1.000000  0.204475  0.076143  0.301392 -0.173551
# 3B  -0.247935 NaN NaN NaN  0.204475  1.000000 -0.393924 -0.458272 -0.133889
# HR   0.326265 NaN NaN NaN  0.076143 -0.393924  1.000000  0.417581  0.385912
# BB   0.478887 NaN NaN NaN  0.301392 -0.458272  0.417581  1.000000  0.238514
# SO   0.124063 NaN NaN NaN -0.173551 -0.133889  0.385912  0.238514  1.000000
# SB  -0.164478 NaN NaN NaN  0.236904  0.508077 -0.179200 -0.107299  0.017165
# RA  -0.812840 NaN NaN NaN -0.228612  0.295742 -0.105691 -0.413502 -0.141401
# ...

# %% [markdown]
# SPLITTING THE COLUMNS

# %%
x=df.drop('W',axis=1)
y=df['W']

# %%
x
# Out:
#       R    AB    H   2B  3B        HR   BB    SO   SB   RA        ER  \
# 0   0.0  5575  0.0  300  42 -0.764626  383   973  104  641 -0.497425
# 1   0.0  5467  0.0  277  44 -0.158581  439  1264   70  700  0.257974
# 2   0.0  5439  0.0  303  29 -0.689676  533  1157   86  640 -0.746906
# 3   0.0  5533  0.0  260  27 -0.879049  404  1231   68  701  0.113575
# 4   0.0  5605  0.0  289  49 -0.329850  455  1259   83  803  1.582654
# 5   0.0  5509  0.0  308  17  1.937860  570  1151   88  670 -0.380464
# 6   0.0  5567  0.0  272  19  1.460099  554  1227   63  698  0.243552
# 7   0.0  5485  0.0  246  20  1.583551  418  1331   44  693  0.156937
# 8   0.0  5485  0.0  278  32  0.200058  436  1310   87  642 -0.453532
# 9   0.0  5640  0.0  294  33  0.007404  478  1148   71  753  0.845910
# 10  0.0  5511  0.0  279  32  0.355503  503  1233  101  733  0.645876
# 11  0.0  5459  0.0  278  26  1.891937  486  1392  121  618 -0.923801
# 12  0.0  5417  0.0  243  21  0.476708  435  1150   52  675 -0.074751
# ...

# %%
y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 5      93
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: W, dtype: int64

# %%
def vif_calc():
  vif=pd.DataFrame()
  vif["VIF Factor"]=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
  vif["features"]=x.columns
  print(vif)

# %%
vif_calc()
# Out:
#       VIF Factor features
# 0            NaN        R
# 1    7906.087245       AB
# 2            NaN        H
# 3     559.282190       2B
# 4      27.374632       3B
# 5       2.620724       HR
# 6     230.410749       BB
# 7     351.595359       SO
# 8      25.368155       SB
# 9   10314.045728       RA
# 10    252.306585       ER
# 11    320.686798      ERA
# 12      2.159101       CG
# 13      2.992984      SHO
# 14      2.588582       SV
# 15     71.163035        E

# %%
x.drop(['H','R'],axis=1,inplace=True)

# %%
vif_calc()
# Out:
#       VIF Factor features
# 0    7906.087245       AB
# 1     559.282190       2B
# 2      27.374632       3B
# 3       2.620724       HR
# 4     230.410749       BB
# 5     351.595359       SO
# 6      25.368155       SB
# 7   10314.045728       RA
# 8     252.306585       ER
# 9     320.686798      ERA
# 10      2.159101       CG
# 11      2.992984      SHO
# 12      2.588582       SV
# 13     71.163035        E

# %% [markdown]
# # Scaling the Data

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 0.84773126,  1.42017307,  1.04119304, -0.76462586, -1.53490242,
#         -2.69762957,  0.91388329, -0.66623393, -0.49742469, -0.50089346,
#         -0.35984364, -0.78957937,  1.546378  , -0.46146963],
#        [-0.71109353,  0.12740339,  1.23580856, -0.15858141, -0.5365919 ,
#          0.15487844, -0.60182558,  0.16597077,  0.25797351,  0.26180619,
#         -0.35984364,  0.25177537,  0.36044386, -0.60719689],
#        [-1.1152333 ,  1.58879521, -0.22380785, -0.68967629,  1.13914361,
#         -0.89398189,  0.11144918, -0.68033909, -0.74690639, -0.63645949,
#          1.99351255, -0.24539345, -0.6075936 , -1.11724227],
#        [ 0.24152162, -0.82812203, -0.41842337, -0.8790486 , -1.16053598,
#         -0.16860185, -0.69098493,  0.18007593,  0.11357524,  0.06080381,
#          1.22010317, -0.51075929, -0.76445333,  0.48575751],
#        [ 1.28073815,  0.80189192,  1.72234737, -0.3298501 , -0.25136033,
# ...

# %% [markdown]
# # As the Outcome is No. Of Matches Won which is in Integer So we use Linear Regression Model

# %%
# importing required liabaries
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
maxAccu=0
maxRS=0
for i in range(1,100):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.30, random_state=i)
    mod = LinearRegression()
    mod.fit(x_train, y_train)
    pred = mod.predict(x_test)
    acc=r2_score(y_test, pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Maximum r2 score is ",maxAccu," on Random_state ",maxRS)
# Out:
# Maximum r2 score is  0.8309152578310199  on Random_state  64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=64)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=maxRS)
print('Training feature matrix size:',x_train.shape)
print('Training target vector size:',y_train.shape)
print('Test feature matrix size:',x_test.shape)
print('Test target vector size:',y_test.shape)
# Out:
# Training feature matrix size: (21, 14)
# Training target vector size: (21,)
# Test feature matrix size: (9, 14)
# Test target vector size: (9,)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression, Lasso,Ridge
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.svm import SVR
from sklearn.linear_model import SGDRegressor
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# %%
# Checking r2score for Linear Regression
LR = LinearRegression()
LR.fit(x_train,y_train)

# prediction
predLR=LR.predict(x_test)
print('R2_score:',r2_score(y_test,predLR))

# Mean Absolute Error (MAE)
print('MAE:',metrics.mean_absolute_error(y_test, predLR))

# Mean Squared Error (MSE)
print('MSE:',metrics.mean_squared_error(y_test, predLR))

# Root Mean Squared Error (RMSE)
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, predLR)))
# Out:
# R2_score: 0.8309152578310199
# MAE: 3.479084409272081
# MSE: 15.184227339964954
# RMSE: 3.8966944119298033

# %% [markdown]
# # Ridge Regression model

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
paramsRidge = {'alpha':[0.01, 0.1, 1.0,10.26], 'solver' : ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga']}
ridge=Ridge()
clf=GridSearchCV(ridge,paramsRidge)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 10.26, 'solver': 'saga'}

# %%
#Checking R2 score for Ridge regression
ridge=Ridge(alpha=10.26,solver='sag')
ridge.fit(x_train,y_train)
ridge.score(x_train,y_train)
pred_ridge=ridge.predict(x_test)
print('R2_Score:',r2_score(y_test,pred_ridge))
print('MAE:',metrics.mean_absolute_error(y_test, pred_ridge))
print('MSE:',metrics.mean_squared_error(y_test, pred_ridge))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, pred_ridge)))
# Out:
# R2_Score: 0.6598496390416997
# MAE: 4.355843041042961
# MSE: 30.546342291489825
# RMSE: 5.526874550004716

# %% [markdown]
# # Lasso Regression

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso,Ridge

parameters={'alpha':[0.0001,0.001,0.01,0.1,1,10],'random_state':list(range(0,100))}
lasso=Lasso()
clf=GridSearchCV(lasso,parameters)
clf.fit(x_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 1, 'random_state': 0}

# %%
lasso=Lasso(alpha=1,random_state=0)
lasso.fit(x_train,y_train)
lasso.score(x_train,y_train)
pred_lasso=lasso.predict(x_test)
print('R2_Score:',r2_score(y_test,pred_lasso))
print('MAE:',metrics.mean_absolute_error(y_test, pred_lasso))
print('MSE:',metrics.mean_squared_error(y_test, pred_lasso))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, pred_lasso)))
# Out:
# R2_Score: 0.7438097335426743
# MAE: 3.917974224547431
# MSE: 23.006518496427002
# RMSE: 4.796511075399181

# %% [markdown]
# # Stochastic Gradient Descent Regression Model

# %%
# Checking R2 score for Stochastic Gradient Descent Regressor
SGD=SGDRegressor()
SGD.fit(x_train,y_train)

# prediction
predSGD=SGD.predict(x_test)
print('R2_Score:',r2_score(y_test,predSGD))
print('MAE:',metrics.mean_absolute_error(y_test, predSGD))
print('MSE:',metrics.mean_squared_error(y_test, predSGD))
print("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, predSGD)))
# Out:
# R2_Score: 0.6732325066111053
# MAE: 4.451253555519656
# MSE: 29.34452773963974
# RMSE: 5.417058956633179

# %% [markdown]
# # Decission Tree Regression

# %%
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
pred=dtr.predict(x_test)
print("predicted result ",pred)
print('actual result',y_test)
# Out:
# predicted result  [ 88. 100. 100.  68.  90.  85.]
# actual result 23    67
# 21    83
# 2     81
# 24    63
# 16    98
# 11    86
# Name: W, dtype: int64

# %%
print('Error:')
print('Mean Absolute Error :',mean_absolute_error(y_test,pred))
print('Mean Squared Error :',mean_squared_error(y_test,pred))
print('Root mean Squared Error',np.sqrt(mean_squared_error(y_test,pred)))
print('r2 score :',r2_score(y_test,pred)*100)
# Out:
# Error:
# Mean Absolute Error : 11.833333333333334
# Mean Squared Error : 196.83333333333334
# Root mean Squared Error 14.02973033715664
# r2 score : -42.747784045124895

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV

parameters = {'alpha':[.0001,.001,.01,.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 1, 'random_state': 0}

# %%
ls=Lasso(alpha=0.1,random_state=0)
ls.fit(x_train,y_train)
ls_score_training=ls.score(x_train,y_train)
pred_ls = ls.predict(x_test)
ls_score_training*100
# Out:
# 87.01016736621932

# %%
from sklearn.ensemble import RandomForestRegressor
Rrf=RandomForestRegressor()

parameters = {'criterion':['mse','mae'],'max_features':["auto","sqrt","log2"]}
clf = GridSearchCV(Rrf,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'sqrt'}

# %%
from sklearn.model_selection import cross_val_score

Rrf= RandomForestRegressor(criterion="mae",max_features="sqrt")
Rrf.fit(x_train,y_train)
Rrf.score(x_train,y_train)
pred_decession = Rrf.predict(x_test)

rfs = r2_score(y_test,pred_decession)
print('R2 Score :',rfs*100)

rfscore = cross_val_score(Rrf,x,y,cv=5)
rfc=rfscore.mean()
print('cross Val Score :',rfc*100)
# Out:
# R2 Score : 61.85161563255441
# cross Val Score : -51.24188247643537

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import  GradientBoostingRegressor
from xgboost import XGBRegressor

rf = RandomForestRegressor(n_estimators = 250 ,max_depth=6)
svr=SVR(C=1.0, epsilon=0.2, kernel='poly', gamma='auto')
dtc = DecisionTreeRegressor(criterion='mse')
adb=AdaBoostRegressor(learning_rate=0.1)
gradb=GradientBoostingRegressor( max_depth=6,learning_rate=0.1)
knn=KNeighborsRegressor(n_neighbors=4,algorithm='kd_tree')
xgb=XGBRegressor()
model = [rf,svr,dtc,adb,gradb,knn,xgb]

for m in model:
    m.fit(x_train,y_train)
    m.score(x_train,y_train)
    y_pred = m.predict(x_test)
    print('\n')                                        
    print('\033[1m'+' Error of ', m, ':' +'\033[0m')
    print('Mean absolute error :', mean_absolute_error(y_test,y_pred))
    print('Mean squared error :', mean_squared_error(y_test,y_pred))
    print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test,y_pred)))
    print('\n')

    print('\033[1m'+' R2 Score :'+'\033[0m')
    print(r2_score(y_test,y_pred)) 
    
    # Cross Validation
    score = cross_val_score(m,x, y, cv =4)
    print('\n')
    print('\033[1m'+'Cross Validation Score :',m,":"+'\033[0m\n')
    print("Mean CV Score :",score.mean())
    print('==============================================================================================================')
# Out:
#  Error of  RandomForestRegressor(max_depth=6, n_estimators=250) :
# Mean absolute error : 5.032644444444447
# Mean squared error : 39.48957861963219
# Root Mean Squared Error: 6.284073409790197
#
#
#  R2 Score :
# 0.5602617723136916
#
#
# Cross Validation Score : RandomForestRegressor(max_depth=6, n_estimators=250) :
#
# Mean CV Score : 0.3411525025537812
# ...
#
#
#  Error of  SVR(epsilon=0.2, gamma='auto', kernel='poly') :
# Mean absolute error : 6.999587518016122
# Mean squared error : 72.7406269579156
# Root Mean Squared Error: 8.528811579459099
#
#
#  R2 Score :
# 0.18999301847798133
#
#
# Cross Validation Score : SVR(epsilon=0.2, gamma='auto', kernel='poly') :
#
# Mean CV Score : 0.08907581175471138
# ...
#
#
#  Error of  DecisionTreeRegressor(criterion='mse') :
# Mean absolute error : 7.333333333333333
# Mean squared error : 93.77777777777777
# Root Mean Squared Error: 9.683892697555967
#
#
#  R2 Score :
# -0.0442672532306847
#
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

model = [LR,lasso,ridge,svr,dtc,adb,gradb,knn,xgb]

for m in model:
    plt.figure(figsize=(7,5))
    m.fit(x_train,y_train)
    y_pred=m.predict(x_test)
    print('\n')
    print('\033[1m'+' True Values Vs Predicted Value plot', m, ':' +'\033[0m')
    sns.scatterplot(y_test.round(2), y_pred)
    plt.xlabel('True Values' , fontsize=15)
    plt.ylabel('Predictions', fontsize=15)
    plt.tight_layout()
    plt.show()
    print('\n')
    print('===================================================================================================')
# Out:
#  True Values Vs Predicted Value plot LinearRegression() :
# ...
#
#
#  True Values Vs Predicted Value plot Lasso(alpha=1, random_state=0) :
# ...
#
#
#  True Values Vs Predicted Value plot Ridge(alpha=10.26, solver='sag') :
# ...
#
#
#  True Values Vs Predicted Value plot SVR(epsilon=0.2, gamma='auto', kernel='poly') :
# ...
#
#
#  True Values Vs Predicted Value plot DecisionTreeRegressor(criterion='mse') :
# ...
#
#
#  True Values Vs Predicted Value plot AdaBoostRegressor(learning_rate=0.1) :
# ...
#
#
#  True Values Vs Predicted Value plot GradientBoostingRegressor(max_depth=6) :
# ...
#
#
#  True Values Vs Predicted Value plot KNeighborsRegressor(algorithm='kd_tree', n_neighbors=4) :
# ...
# [16:39:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
#
#
#  True Values Vs Predicted Value plot XGBRegressor() :
# ...

# %% [markdown]
# # Hyper Parameter Tuning

# %%
#importing necessary libraries
from sklearn.model_selection import GridSearchCV

# %%
print(SGD.get_params())
# Out:
# {'alpha': 0.0001, 'average': False, 'early_stopping': False, 'epsilon': 0.1, 'eta0': 0.01, 'fit_intercept': True, 'l1_ratio': 0.15, 'learning_rate': 'invscaling', 'loss': 'squared_error', 'max_iter': 1000, 'n_iter_no_change': 5, 'penalty': 'l2', 'power_t': 0.25, 'random_state': None, 'shuffle': True, 'tol': 0.001, 'validation_fraction': 0.1, 'verbose': 0, 'warm_start': False}

# %%
parameter = {'alpha':np.array([1,0.5,0.1,0.01,0.001,0.0001]),
             'fit_intercept': [True,False],
             'max_iter':[100,200,250],
             'epsilon':[0.1]}

# %%
GCV = GridSearchCV(SGDRegressor(),parameter,cv=5,verbose = 10)

# %%
GCV.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV 1/5; 1/36] START alpha=1.0, epsilon=0.1, fit_intercept=True, max_iter=100...
# [CV 1/5; 1/36] END alpha=1.0, epsilon=0.1, fit_intercept=True, max_iter=100;, score=0.305 total time=   0.0s
# [CV 2/5; 1/36] START alpha=1.0, epsilon=0.1, fit_intercept=True, max_iter=100...
# [CV 2/5; 1/36] END alpha=1.0, epsilon=0.1, fit_intercept=True, max_iter=100;, score=0.013 total time=   0.0s
# [CV 3/5; 1/36] START alpha=1.0, epsilon=0.1, fit_intercept=True, max_iter=100...
# [CV 3/5; 1/36] END alpha=1.0, epsilon=0.1, fit_intercept=True, max_iter=100;, score=-3.433 total time=   0.0s
# [CV 4/5; 1/36] START alpha=1.0, epsilon=0.1, fit_intercept=True, max_iter=100...
# [CV 4/5; 1/36] END alpha=1.0, epsilon=0.1, fit_intercept=True, max_iter=100;, score=0.524 total time=   0.0s
# [CV 5/5; 1/36] START alpha=1.0, epsilon=0.1, fit_intercept=True, max_iter=100...
# ...

# %%
GCV.best_params_
# Out:
# {'alpha': 1.0, 'epsilon': 0.1, 'fit_intercept': True, 'max_iter': 250}

# %%
ls=Lasso(alpha=0.1,random_state=0)
ls.fit(x_train,y_train)
ls_score_training=ls.score(x_train,y_train)
pred_ls = ls.predict(x_test)
ls_score_training*100
# Out:
# 84.85612784650438

# %% [markdown]
# # saving the Best Model

# %%
import pickle
filename = 'Baseball.pkl'
pickle.dump(ls,open(filename,'wb'))

# %% [markdown]
# # final accuracy rate is 85 %
